# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Project overview
# This is the **Data exploration** project. It deals with the big amount of data connected to the global terrorism.

# %% [markdown]
# ### Data
# The dataset is big. It contains information about 181691 acts of terrorism from 1970 through 2017, which are grouped in 135 collumns.

# %%
#reading the data form .csv file
data = pd.read_csv('globalterrorismdb_0718dist.csv', sep=',', encoding = "ISO-8859-1")

# %% [markdown]
# ### Questions to answer
#
# 1. In which year was the highest number of acts of terrorism recorded?
# 2. Which country was the most dangerous from 2013 through 2017?
# 3. What type of weapon was the most common in 2017? Was it different than in 2000, 1980?
# 4. How many people died or was hurt each year in the terrorism attact?
# 5. How has terrorism spread in Middle East and North Africa?

# %% [markdown]
# #### Choosing the data concected with the questions above

# %%
data.rename(columns={'iyear':'Year','country_txt':'Country','region_txt':'Region','target1':'Target','nkill':'Killed','nwound':'Wounded','weaptype1_txt':'Weapon_type'},inplace=True)
data=data[['Year','Country','Region','Killed', 'Wounded', 'Weapon_type']]
# Out:
#         Year             Country                       Region  Killed  \
# 0       1970  Dominican Republic  Central America & Caribbean     1.0
# 1       1970              Mexico                North America     0.0
# 2       1970         Philippines               Southeast Asia     1.0
# 3       1970              Greece               Western Europe     NaN
# 4       1970               Japan                    East Asia     NaN
# 5       1970       United States                North America     0.0
# 6       1970             Uruguay                South America     0.0
# 7       1970       United States                North America     0.0
# 8       1970       United States                North America     0.0
# 9       1970       United States                North America     0.0
# 10      1970       United States                North America     0.0
# 11      1970       United States                North America     0.0
# 12      1970               Italy               Western Europe     0.0
# 13      1970       United States                North America     0.0
# 14      1970       United States                North America     0.0
# 15      1970  East Germany (GDR)               Eastern Europe     NaN
# 16      1970            Ethiopia           Sub-Saharan Africa     1.0
# 17      1970       United States                North America     0.0
# 18      1970       United States                North America     0.0
# 19      1970       United States                North America     0.0
# 20      1970       United States                North America     0.0
# 21      1970             Uruguay                South America     0.0
# 22      1970       United States                North America     0.0
# 23      1970       United States                North America     0.0
# 24      1970       United States                North America     0.0
# 25      1970           Guatemala  Central America & Caribbean     1.0
# 26      1970         Philippines               Southeast Asia     0.0
# 27      1970           Venezuela                South America     0.0
# 28      1970       United States                North America     0.0
# 29      1970       United States                North America     0.0
# ...      ...                 ...                          ...     ...
# 181661  2017               India                   South Asia     1.0
# 181662  2017         Philippines               Southeast Asia     NaN
# 181663  2017               India                   South Asia     0.0
# 181664  2017      United Kingdom               Western Europe     0.0
# 181665  2017               India                   South Asia     0.0
# 181666  2017             Nigeria           Sub-Saharan Africa     NaN
# 181667  2017               Syria   Middle East & North Africa     NaN
# 181668  2017                Iraq   Middle East & North Africa     0.0
# 181669  2017                Iraq   Middle East & North Africa     0.0
# 181670  2017                Iraq   Middle East & North Africa     1.0
# 181671  2017                Iraq   Middle East & North Africa     4.0
# 181672  2017               India                   South Asia     8.0
# 181673  2017         Afghanistan                   South Asia    18.0
# 181674  2017                Iraq   Middle East & North Africa     5.0
# 181675  2017             Somalia           Sub-Saharan Africa     2.0
# 181676  2017         Afghanistan                   South Asia     5.0
# 181677  2017         Philippines               Southeast Asia     0.0
# 181678  2017         Philippines               Southeast Asia     1.0
# 181679  2017                Iraq   Middle East & North Africa    13.0
# 181680  2017             Somalia           Sub-Saharan Africa     0.0
# 181681  2017         Philippines               Southeast Asia     1.0
# 181682  2017               Italy               Western Europe     0.0
# 181683  2017         Afghanistan                   South Asia     6.0
# 181684  2017               India                   South Asia     0.0
# 181685  2017         Afghanistan                   South Asia     0.0
# 181686  2017             Somalia           Sub-Saharan Africa     1.0
# 181687  2017               Syria   Middle East & North Africa     2.0
# 181688  2017         Philippines               Southeast Asia     0.0
# 181689  2017               India                   South Asia     0.0
# 181690  2017         Philippines               Southeast Asia     0.0
#
#         Wounded Weapon_type
# 0           0.0     Unknown
# 1           0.0     Unknown
# 2           0.0     Unknown
# 3           NaN  Explosives
# 4           NaN  Incendiary
# 5           0.0    Firearms
# 6           0.0    Firearms
# 7           0.0  Explosives
# 8           0.0  Incendiary
# 9           0.0  Incendiary
# 10          0.0  Explosives
# 11          0.0  Incendiary
# 12          0.0    Firearms
# 13          0.0  Incendiary
# 14          0.0  Incendiary
# 15          NaN  Explosives
# 16          0.0     Unknown
# 17          0.0  Explosives
# 18          0.0  Explosives
# 19          0.0  Incendiary
# 20          1.0  Incendiary
# 21          0.0    Firearms
# 22          0.0  Explosives
# 23          0.0  Explosives
# 24          0.0  Incendiary
# 25          0.0     Unknown
# 26          0.0  Explosives
# 27          0.0     Unknown
# 28          0.0  Explosives
# 29          0.0  Incendiary
# ...         ...         ...
# 181661      0.0  Incendiary
# 181662      2.0  Explosives
# 181663      0.0  Explosives
# 181664      2.0    Firearms
# 181665      0.0    Firearms
# 181666      NaN     Unknown
# 181667      NaN  Explosives
# 181668      0.0  Explosives
# 181669      5.0  Explosives
# 181670      0.0     Unknown
# 181671      9.0  Explosives
# 181672      3.0  Explosives
# 181673     14.0  Explosives
# 181674      0.0     Unknown
# 181675      3.0  Explosives
# 181676      0.0  Explosives
# 181677      0.0    Firearms
# 181678      1.0  Explosives
# 181679      0.0    Firearms
# 181680      0.0  Explosives
# 181681      5.0  Explosives
# 181682      0.0  Incendiary
# 181683      0.0    Firearms
# 181684      0.0    Firearms
# 181685      4.0  Explosives
# 181686      2.0    Firearms
# 181687      7.0  Explosives
# 181688      0.0  Incendiary
# 181689      0.0  Explosives
# 181690      0.0  Explosives
#
# [181691 rows x 6 columns]

# %% [markdown]
# #### Ad.1
# The figure below shows the number of terrorist attacts each year. Also the year, in which was the highest number of acts of terrorism recorded, is presented.

# %%
plt.subplots(figsize=(14,6))
sns.countplot('Year',data=data,palette='Set2')
sns.set(style="darkgrid")
plt.xticks(rotation=90)
plt.title('Number of terrorist attacts each year')
plt.show()
print('The year in which was the highest number of acts of terrorism recorded :',data['Year'].value_counts().index[0])
# Out:
# The year in which was the highest number of acts of terrorism recorded : 2014

# %% [markdown]
# #### Ad.2
# The figure below shows the countries with the highest number of terrorist attacts from 2013 through 2017. To sum up, the country, in which was the highest number of acts of terrorism recorded, is presented.

# %%
data1=data[data['Year']>2012]
#for better visualozation 15 countires selected
sns.barplot(data1['Country'].value_counts()[:15].values,data1['Country'].value_counts()[:15].index,palette=('Set1'))
plt.xticks(rotation=90)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.title('Countries with Highest Terror Attacks 2013-2017')
plt.show()
print('The country in which was the highest number of acts of terrorism recorded form 2013 through 2017:',data1['Country'].value_counts().index[0])
# Out:
# The country in which was the highest number of acts of terrorism recorded form 2013 trough 2017: Iraq

# %% [markdown]
# #### Ad.3
#
# The figure below shows two the type of weapon that are most commonly used in terrorist attacks.  Also the  weapon type, that was the most 'popular' in 2017 and 1980, is presented.

# %%
data2=data[data['Weapon_type'].isin(data['Weapon_type'].value_counts()[:2].index)]
pd.crosstab(data2.Year,data.Weapon_type).plot(color=sns.color_palette('Set2',10))
fig=plt.gcf()
fig.set_size_inches(18,6)
plt.title('Two the most common weapon types')
plt.show()

data2017=data[data['Year']==2017]
data1980=data[data['Year']==1980]
print('The type of weapon which was the most common in 2017:',data2017['Weapon_type'].value_counts().index[0])
print('The type of weapon which was the most common in 1980:',data1980['Weapon_type'].value_counts().index[0])
# Out:
# The type of weapon which was the most common in 2017: Explosives
# The type of weapon which was the most common in 1980: Firearms

# %% [markdown]
# #### Ad.4
#
# The text below shows when the highest number of casualities of terrorism was recorded.

# %%
data['casualities']=data['Killed']+data['Wounded']

print('The highest number of casualities of terrorism was recorded :',data['casualities'].max(), 'in', data.loc[data['casualities'].idxmax()].Year )
print('Maximum people killed in an attack are:',data['Killed'].max(),'that took place in',data.loc[data['Killed'].idxmax()].Country)
print('Maximum people hurted in an attack are:',data['Wounded'].max(),'that took place in',data.loc[data['Wounded'].idxmax()].Country)
# Out:
# The highest number of casualities of terrorism was recorded : 9574.0 in 2001
# Maximum people killed in an attack are: 1570.0 that took place in Iraq
# Maximum people hurted in an attack are: 8191.0 that took place in United States

# %% [markdown]
# #### Ad.5
#
# The figure below shows the numbers of attacks in the Middle East & North Africa. We can observe that after the war in 2011 the number of act of terrorism increased rapidly.

# %%
query = data.where(data.Region.str.startswith('Middle East & North Africa'))
dataMENA = query.dropna(how='all')
x = dataMENA['Year'].value_counts().sort_index()
plt.subplots(figsize=(14,6))
plt.plot(x)
plt.title('Terrorism attacks in Middle East & North Africa')
plt.show()
